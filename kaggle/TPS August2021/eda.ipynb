# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

# %%
train = pd.read_csv('../../data/tabular-playground-series-aug-2021/train.csv')
test = pd.read_csv('../../data/tabular-playground-series-aug-2021/test.csv')
sample_submission = pd.read_csv('../../data/tabular-playground-series-aug-2021/sample_submission.csv')

# %%
train.head(10)
# Out:
#    id        f0   f1        f2        f3           f4        f5        f6  \
# 0   0 -0.002350   59  0.766739 -1.350460     42.27270  16.68570   30.3599
# 1   1  0.784462  145 -0.463845 -0.530421  27324.90000   3.47545  160.4980
# 2   2  0.317816   19 -0.432571 -0.382644   1383.26000  19.71290   31.1026
# 3   3  0.210753   17 -0.616454  0.946362   -119.25300   4.08235  185.2570
# 4   4  0.439671   20  0.968126 -0.092546     74.30200  12.30650   72.1860
# 5   5  0.105165  106  0.007932  1.276660   3165.14000   1.67015  155.5780
# 6   6  0.601966    9 -0.133924 -0.098238    734.58300   5.86411   16.6928
# 7   7  0.177120   11 -0.361778  0.492327     -9.01574   6.56938  211.4200
# 8   8  0.216817   50  0.935978 -0.086906    213.43600   5.13950  136.7050
# 9   9  0.656791   14 -0.504919  1.547640    153.81300   6.49644   59.2214
#
#          f7          f8  ...          f91        f92      f93       f94  \
# 0  1.267300    0.392007  ...    -42.43990  26.854000  1.45751  0.696161
# 1  0.828007    3.735860  ...   -184.13200   7.901370  1.70644 -0.494699
# 2 -0.515354   34.430800  ...      7.43721  37.218100  3.25339  0.337934
# 3  1.383310  -47.521400  ...      9.66778   0.626942  1.49425  0.517513
# 4 -0.233964   24.399100  ...    290.65700  15.604300  1.73557 -0.476668
# 5  0.782602  -16.373700  ...   5168.03000  33.917900  1.62149  1.082260
# 6  0.714386   -9.909540  ...    -49.42170  28.144900  1.87039  0.417755
# 7 -0.841209   16.011500  ...     -5.51494  42.106500  1.79785 -0.197997
# 8  1.154870  113.220000  ...  17560.20000  44.787400  1.49904  0.736440
# 9  0.619670  -37.125200  ...     51.70010  12.243400  1.85891  0.061177
#
#          f95       f96       f97      f98       f99  loss
# 0   0.941764  1.828470  0.924090  2.29658  10.48980    15
# 1  -2.058300  0.819184  0.439152  2.36470   1.14383     3
# 2   0.615037  2.216760  0.745268  1.69679  12.30550     6
# 3 -10.222100  2.627310  0.617270  1.45645  10.02880     2
# 4   1.390190  2.195740  0.826987  1.78485   7.07197     1
# 5  -3.972420  0.500732  0.628588  2.45744   7.23832    16
# 6   4.880680  2.884050  0.115900  1.12773   3.48813     4
# 7   5.953100  2.695590  0.487619  1.23021   7.07088     5
# 8   4.647110  2.097610  0.302990  2.09165   9.73664     7
# 9  -2.514130  1.478190  0.513508  1.27266   2.31615     4
#
# [10 rows x 102 columns]

# %%
test.head()
# Out:
#        id        f0   f1        f2        f3          f4        f5         f6  \
# 0  250000  0.812665   15 -1.239120 -0.893251    295.5770  15.87120   23.04360
# 1  250001  0.190344  131 -0.501361  0.801921     64.8866   3.09703  344.80500
# 2  250002  0.919671   19 -0.057382  0.901419  11961.2000  16.39650  273.24000
# 3  250003  0.860985   19 -0.549509  0.471799   7501.6000   2.80698   71.08170
# 4  250004  0.313229   89  0.588509  0.167705   2931.2600   4.34986    1.57187
#
#          f7         f8  ...       f90        f91       f92      f93       f94  \
# 0  0.942256  29.898000  ...  0.446389   -422.332  -1.44630  1.69075  1.059300
# 1  0.807194  38.421900  ...  0.377179  10352.200  21.06270  1.84351  0.251895
# 2 -0.003300  37.940000  ...  0.990140   3224.020  -2.25287  1.55100 -0.559157
# 3  0.792136   0.395235  ...  1.396880   9689.760  14.77150  1.41390  0.329272
# 4  1.118300   7.754630  ...  0.862502   2693.350  44.18050  1.58020 -0.191021
#
#          f95      f96       f97       f98       f99
# 0  -3.010570  1.94664  0.529470  1.386950   8.78767
# 1   4.440570  1.90309  0.248534  0.863881  11.79390
# 2  17.838600  1.83385  0.931796  2.336870   9.05400
# 3   0.802437  2.23251  0.893348  1.359470   4.84833
# 4  26.253000  2.68238  0.361923  1.532800   3.70660
#
# [5 rows x 101 columns]

# %%
print(f'Train Shape :  {train.shape}')
print(f'Test Shape :  {test.shape}')
# Out:
# Train Shape :  (250000, 102)
# Test Shape :  (150000, 101)

# %%
target = train['loss']
train.drop(['id'],axis=1,inplace=True)
test.drop(['id'],axis=1,inplace=True)

# %%
train.head()
# Out:
#          f0   f1        f2        f3          f4        f5        f6  \
# 0 -0.002350   59  0.766739 -1.350460     42.2727  16.68570   30.3599
# 1  0.784462  145 -0.463845 -0.530421  27324.9000   3.47545  160.4980
# 2  0.317816   19 -0.432571 -0.382644   1383.2600  19.71290   31.1026
# 3  0.210753   17 -0.616454  0.946362   -119.2530   4.08235  185.2570
# 4  0.439671   20  0.968126 -0.092546     74.3020  12.30650   72.1860
#
#          f7         f8       f9  ...        f91        f92      f93       f94  \
# 0  1.267300   0.392007  1.09101  ...  -42.43990  26.854000  1.45751  0.696161
# 1  0.828007   3.735860  1.28138  ... -184.13200   7.901370  1.70644 -0.494699
# 2 -0.515354  34.430800  1.24210  ...    7.43721  37.218100  3.25339  0.337934
# 3  1.383310 -47.521400  1.09130  ...    9.66778   0.626942  1.49425  0.517513
# 4 -0.233964  24.399100  1.10151  ...  290.65700  15.604300  1.73557 -0.476668
#
#          f95       f96       f97      f98       f99  loss
# 0   0.941764  1.828470  0.924090  2.29658  10.48980    15
# 1  -2.058300  0.819184  0.439152  2.36470   1.14383     3
# 2   0.615037  2.216760  0.745268  1.69679  12.30550     6
# 3 -10.222100  2.627310  0.617270  1.45645  10.02880     2
# 4   1.390190  2.195740  0.826987  1.78485   7.07197     1
#
# [5 rows x 101 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Columns: 101 entries, f0 to loss
# dtypes: float64(95), int64(6)
# memory usage: 192.6 MB

# %%
tmp = train.isnull().sum()
print(tmp)
# Out:
# f0      0
# f1      0
# f2      0
# f3      0
# f4      0
#        ..
# f96     0
# f97     0
# f98     0
# f99     0
# loss    0
# Length: 101, dtype: int64

# %%
tmp2 = test.isnull().sum()
print(tmp2)
# Out:
# f0     0
# f1     0
# f2     0
# f3     0
# f4     0
#       ..
# f95    0
# f96    0
# f97    0
# f98    0
# f99    0
# Length: 100, dtype: int64

# %%
fig,ax = plt.subplots(1,1,figsize=(17,8))

target_cnt = train["loss"].value_counts().sort_index()

ax.bar(target_cnt.index,target_cnt,color=['#d4dddd' if i%2 == 0 else '#fafafa' for i in range(9)],
      width=0.55,
      edgecolor='black',
      linewidth=0.7)

ax.margins(0.02,0.05)

for i in range(20):
    ax.annotate(f'{target_cnt[i]/len(train)*100:.3}',xy=(i,target_cnt[i]+1000),va='center',ha='center')
    
ax.set_title('Target Distribution',weight='bold',fontsize=15)
ax.grid(axis='y',linestyle='-',alpha=0.4)

fig.tight_layout()
plt.show()

# %%
target_cnt_df = pd.DataFrame(target_cnt)
target_cnt_df['ratio(%)'] = target_cnt_df/target_cnt.sum()*100
target_cnt_df.sort_values('ratio(%)', ascending=False, inplace=True)
target_cnt_df['cummulated_sum(%)'] = target_cnt_df['ratio(%)'].cumsum()
target_cnt_df.style.bar(subset=['cummulated_sum(%)'], color='#205ff2')
# Out:
# <style  type="text/css" >
#     #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 11.7%, transparent 11.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 23.3%, transparent 23.3%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 31.7%, transparent 31.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 38.7%, transparent 38.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 45.3%, transparent 45.3%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 50.9%, transparent 50.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 55.6%, transparent 55.6%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 60.0%, transparent 60.0%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 63.9%, transparent 63.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 67.7%, transparent 67.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 71.2%, transparent 71.2%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 74.2%, transparent 74.2%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 76.7%, transparent 76.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 78.9%, transparent 78.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 80.9%, transparent 80.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 82.8%, transparent 82.8%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 84.6%, transparent 84.6%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 86.3%, transparent 86.3%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 87.9%, transparent 87.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow20_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 89.5%, transparent 89.5%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow21_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 90.8%, transparent 90.8%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow22_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 91.9%, transparent 91.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow23_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 92.9%, transparent 92.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow24_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 93.8%, transparent 93.8%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow25_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 94.6%, transparent 94.6%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow26_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 95.3%, transparent 95.3%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow27_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 96.0%, transparent 96.0%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow28_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 96.6%, transparent 96.6%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow29_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 97.2%, transparent 97.2%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow30_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 97.7%, transparent 97.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow31_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 98.2%, transparent 98.2%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow32_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 98.6%, transparent 98.6%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow33_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.0%, transparent 99.0%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow34_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.3%, transparent 99.3%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow35_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.5%, transparent 99.5%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow36_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.7%, transparent 99.7%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow37_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.9%, transparent 99.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow38_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 99.9%, transparent 99.9%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow39_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 100.0%, transparent 100.0%);
#         }    #T_ee670e1f_fa30_11eb_b48f_244bfe9a729arow40_col2 {

# %%
train.describe().T.style.bar(subset=['mean'],color='#205ff2').background_gradient(subset=['std'],cmap='Reds').background_gradient(subset=['50%'],cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_eeded399_fa30_11eb_ad51_244bfe9a729arow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow4_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow5_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow7_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow7_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow8_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow8_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow9_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow9_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow10_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow10_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow11_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow11_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow12_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow12_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow13_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow13_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow14_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow15_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow15_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 0.2%, transparent 0.2%);
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow16_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow16_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeded399_fa30_11eb_ad51_244bfe9a729arow17_col1 {
#             width:  10em;

# %%
discrete_features = []

for col in train.columns:
    if np.array_equal(train[col].values,train[col].values.astype(int)):
        discrete_features.append(col)
        
print(f'Total{len(discrete_features)}:')
print(discrete_features)
# Out:
# Total6:
# ['f1', 'f16', 'f27', 'f55', 'f86', 'loss']

# %%
for dcol in discrete_features:
    print(f'{dcol} unique value : {train[dcol].nunique()}')
# Out:
# f1 unique value : 289
# f16 unique value : 247476
# f27 unique value : 37471
# f55 unique value : 4726
# f86 unique value : 329
# loss unique value : 43

# %%
f1_loss = train.groupby(['f1'])['loss'].mean().sort_values()
print((f1_loss==0).sum())
# Out:
# 5

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
features = [f'f{i}' for i in range(100)]
train[features] = ss.fit_transform(train[features])
test[features] = ss.transform(test[features])

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
sns.heatmap(train.groupby('loss').mean().sort_index(),
            square=True, center=0, linewidth=1,
            cmap=sns.diverging_palette(240, 10, as_cmap=True),
            cbar=False, 
           )

ax.set_title('Mean : Group by Target(Loss)',loc='left')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
sns.heatmap(train.groupby('loss').mean().sort_index(),
            square=True, vmin=-0.5, vmax=0.5, center=0, linewidth=1,
            cmap=sns.diverging_palette(240, 10, as_cmap=True),
            cbar=False, 
           )

ax.set_title('Mean : Group by Target(Loss)',loc='left')
plt.show()

# %%
fig, axes = plt.subplots(10,10,figsize=(12, 12))
axes = axes.flatten()

for idx, ax in enumerate(axes):
    sns.kdeplot(data=train, x=f'f{idx}', 
                fill=True, 
                ax=ax)
    sns.kdeplot(data=test, x=f'f{idx}', 
                fill=True, 
                ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.spines['left'].set_visible(False)
    ax.set_title(f'f{idx}', loc='right', weight='bold', fontsize=10)

fig.supxlabel('Average by class (by feature)', ha='center', fontweight='bold')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\zaxir\anaconda3\lib\site-packages\seaborn\distributions.py:690: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f9c16f3bdf0c> in <module>
#       3
#       4 for idx, ax in enumerate(axes):
# ----> 5     sns.kdeplot(data=train, x=f'f{idx}',
#       6                 fill=True,
#       7                 ax=ax)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     694                         "supported for bivariate distributions.")
#     695     if bivariate:
# --> 696         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     697                                 kernel, bw, gridsize, cut, clip, legend,
#     698                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#
# TypeError: _bivariate_kdeplot() got multiple values for argument 'x'

# %%
fig, ax = plt.subplots(1, 1, figsize=(12 , 12))

corr = train.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, ax=ax,
        square=True, center=0, linewidth=1,
        cmap=sns.diverging_palette(240, 10, as_cmap=True),
        cbar_kws={"shrink": .82},    
        mask=mask
       ) 

ax.set_title(f'Correlation', loc='left', fontweight='bold')     

plt.show()
